# %%
# Notebook Cell 1: Compute and Save Bertz Scores

import os
import pandas as pd
from rdkit import Chem
from rdkit.Chem.GraphDescriptors import BertzCT
from rdkit.Chem import rdMolDescriptors
from tqdm import tqdm

# ---------------------------
# CONFIGURATION
# ---------------------------
input_csv = "../pubchem/train_200k.csv"  # Input CSV file
output_dir = "../indigo_simple_render"
os.makedirs(output_dir, exist_ok=True)
bertz_csv = os.path.join(output_dir, "bertz_scores.csv")

# ---------------------------
# STEP 1: READ CSV & COMPUTE MOLECULE PROPERTIES
# ---------------------------
# The CSV is assumed to have at least the following columns:
# pubchem_cid, InChI, SMILES, num_atoms
df = pd.read_csv(input_csv)

molecule_data = []
print("Computing Bertz scores and other properties...")
for idx, row in tqdm(df.iterrows(), total=len(df), desc="Processing molecules"):
    smiles = row['SMILES']
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol is None:
            continue
        # Compute Bertz complexity
        bertz = BertzCT(mol)
        # Compute total hydrogen atom count (implicit + explicit)
        hydrogen_count = sum(atom.GetTotalNumHs() for atom in mol.GetAtoms())
        # Check if molecule has aromatic rings (using RDKit's descriptor)
        num_aromatic_rings = rdMolDescriptors.CalcNumAromaticRings(mol)
        has_aromatic = num_aromatic_rings > 0
        
        molecule_data.append({
            "pubchem_cid": row["pubchem_cid"],
            "SMILES": smiles,
            "bertz": bertz,
            "hydrogen_atom_count": hydrogen_count,
            "has_aromatic_ring": has_aromatic
        })
    except Exception as e:
        print(f"Error processing index {idx} with SMILES '{smiles}': {e}")

# Convert to DataFrame and save all molecule data (including Bertz scores)
molecule_df = pd.DataFrame(molecule_data)
molecule_df.to_csv(bertz_csv, index=False)
print(f"Saved Bertz scores and molecule properties for {len(molecule_df)} molecules to {bertz_csv}")
# Out:
# Computing Bertz scores and other properties...
# Processing molecules:   2%|▏         | 4734/200000 [00:04<03:22, 965.02it/s] [22:29:09] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:   4%|▍         | 8582/200000 [00:08<03:05, 1033.71it/s][22:29:13] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:   5%|▍         | 9906/200000 [00:10<03:13, 980.14it/s] [22:29:14] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  17%|█▋        | 34140/200000 [00:34<02:48, 986.68it/s] [22:29:39] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  18%|█▊        | 36420/200000 [00:36<02:49, 962.94it/s] [22:29:41] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  18%|█▊        | 36717/200000 [00:37<02:47, 972.60it/s][22:29:41] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  20%|█▉        | 39006/200000 [00:39<02:36, 1030.56it/s][22:29:44] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  22%|██▏       | 43474/200000 [00:43<02:39, 982.19it/s] [22:29:48] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  28%|██▊       | 55928/200000 [00:56<02:36, 920.47it/s] [22:30:01] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  30%|██▉       | 59085/200000 [00:59<02:19, 1006.81it/s][22:30:04] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  37%|███▋      | 73344/200000 [01:13<02:09, 978.96it/s] [22:30:18] WARNING: not removing hydrogen atom without neighbors
# [22:30:18] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  40%|████      | 80819/200000 [01:21<01:54, 1039.97it/s][22:30:26] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  42%|████▏     | 83549/200000 [01:24<01:56, 1003.28it/s][22:30:29] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  44%|████▍     | 88716/200000 [01:29<01:52, 993.22it/s] [22:30:34] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  48%|████▊     | 96124/200000 [01:36<01:42, 1015.38it/s][22:30:41] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  50%|████▉     | 99718/200000 [01:40<01:41, 985.75it/s] [22:30:45] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  52%|█████▏    | 104294/200000 [01:45<01:35, 997.24it/s] [22:30:49] Conflicting single bond directions around double bond at index 16.
# [22:30:49]   BondStereo set to STEREONONE and single bond directions set to NONE.
# Processing molecules:  56%|█████▋    | 112853/200000 [01:53<01:26, 1008.83it/s][22:30:58] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  64%|██████▍   | 128429/200000 [02:09<01:09, 1036.13it/s][22:31:14] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  79%|███████▉  | 158910/200000 [02:40<00:42, 975.08it/s] [22:31:45] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  83%|████████▎ | 165839/200000 [02:48<00:39, 861.94it/s] [22:31:52] WARNING: not removing hydrogen atom without neighbors
# [22:31:52] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  84%|████████▎ | 167018/200000 [02:49<00:34, 947.53it/s][22:31:54] WARNING: not removing hydrogen atom without neighbors
# Processing molecules:  92%|█████████▏| 183296/200000 [03:05<00:16, 1009.99it/s][22:32:10] WARNING: not removing hydrogen atom without neighbors
# Processing molecules: 100%|██████████| 200000/200000 [03:22<00:00, 986.15it/s]
# Saved Bertz scores and molecule properties for 200000 molecules to indigo_simple_render/bertz_scores.csv

# %%
# Notebook Cell 2: Render Images for Simplest Molecules (Final Version with White Background & Error Handling)

import os
import pandas as pd
from indigo import Indigo
from indigo.renderer import IndigoRenderer
from tqdm import tqdm

# ---------------------------
# CONFIGURATION
# ---------------------------
bertz_csv = "indigo_simple_render/bertz_scores.csv"  # CSV generated from Notebook Cell 1
output_dir = "indigo_simple_render"
images_dir = os.path.join(output_dir, "images")
output_csv = os.path.join(output_dir, "simple molecules.csv")
os.makedirs(images_dir, exist_ok=True)

# ---------------------------
# STEP 1: LOAD THE MOLECULE PROPERTIES CSV
# ---------------------------
df = pd.read_csv(bertz_csv)

# Filter out entries with Bertz score of 0 (assumed to be invalid molecules)
df = df[df["bertz"] > 0]

# Sort by Bertz complexity (lowest complexity first) and select 5000 molecules
simple_df = df.sort_values(by="bertz").head(5000)
print(f"Selected {len(simple_df)} molecules with the simplest Bertz complexity (excluding bertz==0).")

# ---------------------------
# STEP 2: SET UP INDIGO INSTANCE & INDIGO RENDERER
# ---------------------------
indigo = Indigo()
renderer = IndigoRenderer(indigo)  # Use IndigoRenderer for rendering

# ---------------------------
# STEP 3: RENDER MOLECULES AS IMAGES
# ---------------------------
output_records = []
print("Rendering images for each molecule...")

for _, row in tqdm(simple_df.iterrows(), total=len(simple_df), desc="Rendering Images"):
    smiles = row["SMILES"]
    try:
        # Load the molecule into Indigo
        indigo_mol = indigo.loadMolecule(smiles)
        # Set rendering options for white background
        indigo.setOption("render-background-color", "1, 1, 1")  # White background
        # Compute a 2D layout to improve rendering
        indigo_mol.layout()
    except Exception as e:
        print(f"Indigo failed to load molecule '{smiles}': {e}")
        continue  # Skip this molecule if it fails to load

    # Create an image ID using the PubChem CID
    image_id = f"mol_{row['pubchem_cid']}"
    file_name = f"{image_id}.png"
    file_path = os.path.join(images_dir, file_name)

    try:
        # Render and save the image using IndigoRenderer
        IndigoRenderer.renderToFile(renderer, obj=indigo_mol, filename=file_path)
    except Exception as e:
        print(f"Failed to render molecule '{smiles}': {e}")
        continue  # Skip this molecule if rendering fails

    # If successfully rendered, add to CSV
    output_records.append({
        "image_id": image_id,
        "file_path": file_path,
        "SMILES": smiles,
        "hydrogen_atom_count": row["hydrogen_atom_count"],
        "has_aromatic_ring": row["has_aromatic_ring"]
    })

# ---------------------------
# STEP 4: SAVE THE OUTPUT CSV
# ---------------------------
output_df = pd.DataFrame(output_records)
output_df.to_csv(output_csv, index=False)
print(f"Rendered {len(output_records)} molecules. CSV saved at {output_csv}")

# ---------------------------
# STEP 4: SAVE THE OUTPUT CSV
# ---------------------------
output_df = pd.DataFrame(output_records)
output_df.to_csv(output_csv, index=False)
print(f"Rendered {len(output_records)} molecules. CSV saved at {output_csv}")
# Out:
# Selected 5000 molecules with the simplest Bertz complexity (excluding bertz==0).
# Rendering images for each molecule...
# Rendering Images:   8%|▊         | 424/5000 [00:00<00:01, 4234.53it/s]
# Failed to render molecule 'C.[Si]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Li+].[AlH4-]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'S.[Mn]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Mg]=S': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C.[Pd]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'P.[Tl]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'S=[Rh]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'O.[Al]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CO': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[F-].[Cs+]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[NH4+].[F-]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'O.[Cd]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'N[O-]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Li+].[In]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[AlH3].[AlH3].[Yb]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'Br[Re]Br': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'O.O.[Mg]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[O-2].[O-2].[125Te+4]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CC[GeH3]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CC[SiH3]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[CH3-].[CH3+].[Ru]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'OI=O': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[O-2].[O-2].[Cr+6]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'F[Er]F': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'I[U]I': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Cl-].Cl[Cu]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[O-2].[Fe+2].[Fe+3]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Si].[Si].[Cr]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'Br[Eu]Br': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[S-2].[S-2].[Hf+4]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'Br[Cd]Br': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[CH](I)I': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'Cl[Cr]Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'O.[Cd].[Cd]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[CH-](Cl)Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C[OH+]C': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[AlH3].[AlH3].[Y]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CCF': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'Br[Pt]Br': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C[11CH2]O': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Ga].[Ga].[Te]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Cu].[Cu].[Cu].[Zn]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Cl-].[Cl-].[Cl-].[Eu+3]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[F-].[F-].[F-].[F-].[239Pu]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[OH-].[OH-].[OH-].[OH-].[Al+3]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[OH-].[OH-].[O-2].[O-2].[W]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'O.O.O.O.O.[Co]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'O.O.O.O.O.[Mn]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Na+].[Na+].[Cl-].[Cl-]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'O.O.O.O.O.O.[Ru+2]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'N.N.N.N.N.N.[Ni+2]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'O.O.O.O.O.O.[Sb]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C[Hg].O': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'Cl[Hg]I': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[F-].[Ca+2].[I-]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Li].[Pd].[Pt]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[F-].[Cl-].[Sr+2]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[CH2-]I.[Mn]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[CH3-].[Cl-].[Ca+2]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'O=[Sb].Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[NH4+].[OH-].Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'Br[Ag]I': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Ce]#[Ce]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[S-2].[S-2].[S-2].[In+3].[In+3]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[CH2]CCN': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[O-2].[O-2].[K+].[Fe+3]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Li+].[CH-](Cl)Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'P#[La]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'N#[Ti]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[C-]#[Zr+]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Ni]#[Sb]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'N#[Ni]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[O-2].[O-2].[O-2].[Ti+4].[Ni+2]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'O.O.O.[Ti].[Mn]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Se-2].[Se-2].[Se-2].[Se-2].[Se-2].[Se-2].[Se-2].[Re].[Re]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'O=[W].Cl.Cl.Cl.Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C#[C-].[U]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C1CN1': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C[O-].C[O-].[Co+2]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[NH2-].[NH2-].[Pd](I)I': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Si].[Si].[Si].[Ti].[Ti].[Ti].[Ti].[Ti]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'O.[Ca].[Fe].[Nd]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'Cl[Sn+](Cl)Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'Cl[59Fe](Cl)Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Si](Br)(Br)Br': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C[14CH](C)O': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C[C](C)F': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'O.[Cu].[Y].[Ba]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'I[Tm](I)I': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'Cl[106Ru](Cl)Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'Br[Tb](Br)Br': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[10B](O)(O)O': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[OH-].[OH-].[OH-].[OH-].[OH-].[OH-].[Na+].[Sb]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[F-].[F-].[F-].[F-].[F-].[F-].[Si+4].[Ni+2]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[O-2].[O-2].[O-2].[Na+].[Na+].[Ti+4]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C[SiH](C)[SiH3]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C.C.C.C.C.C.C.[Cr].[Cr].[Cr]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CCCN.Br': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Li+].C(CN)N': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Br-].[Br-].[Br-].[Br-].[Pd+2].[Cs+].[Cs+]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C(F)[SiH2]Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'NN=O': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C=NN': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[2H]C(Cl)Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[2H]C([2H])Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CN(C)O': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C[As]([O-])[O-]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CCCC[S-]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[BH2-](CC)CC': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CC[SnH]CC': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[P]1[P][P][P][P]1': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C(CO)N.[Cu]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CN(C)C.[AlH3]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C(=O)Br': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C[C-](C)C.Cl[Zn+]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[CH3-].[CH3-].[CH3-].[Al+2]Cl.[Al+](Cl)Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[SH-].[SH-].[SH-].[SH-].[Fe].[Fe].[Fe].[Fe].[Ni]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C(Cl)(Br)I': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Li+].C[CH-]C.[Mg+2].[Cl-].[Cl-]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'N.N.N.N.N.N.[Cl-].[Cl-].[Cl-].[Ru+3]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[K+].[K+].[K+].[Br-].[Br-].[Br-].[Br-].[Br-].[Br-].[Ir+3]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[SH-].[SH-].[SH-].[SH-].[SH-].[Fe].[Fe].[Fe].[Fe].[Ni]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[B].[Fe].[Fe].[Fe].[Fe].[Fe].[Fe].[Fe].[Fe].[Fe].[Fe].[Fe].[Fe].[Fe].[Fe].[Nd].[Nd]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[O-2].[O-2].[O-2].[O-2].[O-2].[O-2].[O-2].[Ti+4].[Ti+4].[Fe+3].[Fe+3]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'N.N.N.Cl[Rh](Cl)Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CCCC[NH-].[Na+]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CCCC[S-].[K+]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C(C[11CH2]N)CN': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[BH3-]C(C)CC': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[O-]Cl=O.[O-]Cl=O.[O-]Cl=O.[Fe+3]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C[N-]C.C[N-]C.C[N-]C.[Al+3]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Li+].CCC(C)[CH2-]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C(C(N)N)N': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CCC[S-].CCC[S-].[Hg+2]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CC(C)(C)[As]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C#[C-].C#[C-].[Pt+2]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'F[Nb](F)(F)F': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[O-][Si]([O-])([O-])[O-]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'Br[Hf](Br)(Br)Br': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'Cl[Fe-](Cl)(Cl)Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CSCCCO': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CCCC[Te]I': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CC[Sn]=O': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CC(C)[CH2-].CC(C)[CH2-].[Zn+2]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[N-]=O.[N-]=O.[N-]=O.[N-]=O.[Cr+4]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C[SiH](C)CCl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'NOP(O)O': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CC(CBr)N': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CC[NH-].CC[NH-].I[Pt+2]I': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[As]1[I-][As][I-][As][I-]1': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CC[Ge](Cl)Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[F-].[F-].[F-].[F-].[F-].[F-].[F-].[F-].[F-].[F-].[F-].[F-].[F-].[F-].[F-].[F-].[F-].[F-].[Si+4].[Si+4].[Si+4].[Ce+3].[Ce+3]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C(CN)N.[Cl-].[Cl-].[Br-].[Br-].[Pt+4]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[H+].C[C@@H](CO)O': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[CH3-].Cl[Ta](Cl)(Cl)Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[B-].C[N+](C)(C)C': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'N#[O+].N#[O+].[Mo]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C[Te](C)(Cl)Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C(C[NH-])[NH-].Cl[Pt+2]Br': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'B(OC)(Br)Br': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[11C](=O)=O': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C(=[Co])=[Co]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Se]=[Th]=[Se]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C=[N+]=C': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'O=[P+]=O': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CCO.CCO.CCO.CCO.[Ti]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[13CH3][13C]#[15N]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C[N+]#[C-]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C#CO': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C#CCl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C[C@H](CO)OC': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CCN(CC)N': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CC#[C-].[Cu+]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CC(C)CCS': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CCC[As](C)C': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CCCC(C)S': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Na].[Na].Cl[Pt](Cl)(Cl)Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C1CNCCN1.Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C1CN1Br': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C1[C@H](O1)Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C(=[SH+])(S)S': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CC(=C)F': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'OS(=O)[O-]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[O-]I(=O)=O.[O-]I(=O)=O.[Cu+2]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Li+].[Li+].[Cl-].[Cl-].Cl[Ru](Cl)(Cl)Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[O-]I(=O)=O.[O-]I(=O)=O.[Ba+2]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[Cl-].[Cl-].Cl[Re](Cl)(Cl)Cl.[K+].[K+]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'B(CC)(CC)N': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CCCC(I)I': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CC[C@@H](CO)N': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CCC(C[Sn])O': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CC(C)[CH2-].Cl[Ti+](Cl)Cl': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[C-]#N.[C-]#N.[K+].[Au+]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule '[2H]C(=C)[2H]': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'C(CCCl)CCI': renderToFile() missing 1 required positional argument: 'self'
# Failed to render molecule 'CCC(C